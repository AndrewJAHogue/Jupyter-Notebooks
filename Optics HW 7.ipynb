# %% [markdown]
# 2. lambda = 560 nm
# plot intensity as function of fringe seperation

# %%
import sympy as s
import matplotlib.pyplot as plt
from sympy import cos, sin, pi
from sympy.abc import L, lamda, d, y

# %%
lamda1 = 560e-9
y1 = 5.6e-3
L1 = 10
d1 = 1e-3

# %%
I0 = s.Symbol('I0')
I = 4*I0*cos(y*d*pi / (L*lamda))**2
I
# Out:
# 4*I0*cos(pi*d*y/(L*lamda))**2

# %%
I = 4*I0*cos(y*d / (L*lamda))**2
expr = I.evalf(subs={lamda: lamda1, L: L1, d: d1, I0: 1})
import numpy as np
xvalues = np.arange(0, 4, .1)
yvalues = np.array([])
# yvalues = 4*np.cos(xvalues/(lamda1))**2
for x in xvalues:
    yvalues = np.append(yvalues, I.evalf(subs={y: x, I0: 1, d: 1, L: 1, lamda: lamda1}))

# %%
# plt.ylim(top=1)
# plt.ylim(bottom=0)
# plt.xlim(right=5)
plt.plot(xvalues, yvalues)

# %%
lamda2 = 337e-9
yvalues = 4*np.cos(xvalues/(lamda2))**2

# %%
plt.plot(xvalues, yvalues)

# %%
lamda3 = 1064e-9
del yvalues
yvalues = 4*np.cos(xvalues/(lamda3))**2

# %%
plt.plot(xvalues, yvalues)

# %% [markdown]
# I have no idea why this one won't plot, I'm doing it correctly
